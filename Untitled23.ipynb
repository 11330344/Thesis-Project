# %% [markdown]
# <a href="https://colab.research.google.com/github/11330344/Thesis-Project/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from sklearn.model_selection import train_test_split

# Load the FER2013 dataset (replace with your actual file path)
df = pd.read_csv('/content/drive/MyDrive/Thesis2024/fer2013.csv')

# Extract pixel values and labels
pixels = df['pixels'].apply(lambda x: np.array(x.split(), dtype='float32'))
labels = df['emotion']

# Normalize pixel values
pixels /= 255.0

# Reshape pixel arrays to (48, 48, 1)
X_train = np.stack(pixels.values).reshape(-1, 48, 48, 1)
Y_train = labels.values
# Out:
# Mounted at /content/drive

# %%
# Split the data into training, validation, and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))  # 7 emotions: anger, disgust, fear, happiness, sadness, surprise, neutral

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Implement early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/100
# 359/359 [==============================] - 10s 10ms/step - loss: 1.7375 - accuracy: 0.3218 - val_loss: 2.0584 - val_accuracy: 0.1848
# Epoch 2/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.5330 - accuracy: 0.3985 - val_loss: 1.4989 - val_accuracy: 0.4136
# Epoch 3/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.4391 - accuracy: 0.4358 - val_loss: 1.4316 - val_accuracy: 0.4702
# Epoch 4/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.3701 - accuracy: 0.4697 - val_loss: 1.4389 - val_accuracy: 0.4549
# Epoch 5/100
# 359/359 [==============================] - 3s 8ms/step - loss: 1.3072 - accuracy: 0.4934 - val_loss: 1.3150 - val_accuracy: 0.4993
# Epoch 6/100
# 359/359 [==============================] - 3s 8ms/step - loss: 1.2537 - accuracy: 0.5152 - val_loss: 1.3714 - val_accuracy: 0.4753
# Epoch 7/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.1933 - accuracy: 0.5399 - val_loss: 1.2659 - val_accuracy: 0.5275
# Epoch 8/100
# 359/359 [==============================] - 3s 8ms/step - loss: 1.1512 - accuracy: 0.5548 - val_loss: 1.2432 - val_accuracy: 0.5350
# Epoch 9/100
# 359/359 [==============================] - 3s 8ms/step - loss: 1.0854 - accuracy: 0.5797 - val_loss: 1.4692 - val_accuracy: 0.4972
# Epoch 10/100
# 359/359 [==============================] - 3s 8ms/step - loss: 1.0320 - accuracy: 0.6006 - val_loss: 1.3489 - val_accuracy: 0.5129
# Epoch 11/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.9862 - accuracy: 0.6192 - val_loss: 1.2466 - val_accuracy: 0.5406
# Epoch 12/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.9310 - accuracy: 0.6415 - val_loss: 1.3607 - val_accuracy: 0.5484
# Epoch 13/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.8758 - accuracy: 0.6618 - val_loss: 1.3559 - val_accuracy: 0.5282
# Epoch 14/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.8270 - accuracy: 0.6816 - val_loss: 1.3516 - val_accuracy: 0.5176
# Epoch 15/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.7910 - accuracy: 0.6952 - val_loss: 1.3344 - val_accuracy: 0.5650
# Epoch 16/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.7218 - accuracy: 0.7209 - val_loss: 1.4994 - val_accuracy: 0.5421
# Epoch 17/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.6912 - accuracy: 0.7333 - val_loss: 1.4595 - val_accuracy: 0.5517
# Epoch 18/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.6514 - accuracy: 0.7480 - val_loss: 1.5168 - val_accuracy: 0.5455
# Epoch 19/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.6062 - accuracy: 0.7631 - val_loss: 1.7340 - val_accuracy: 0.5136
# Epoch 20/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.5766 - accuracy: 0.7813 - val_loss: 1.7165 - val_accuracy: 0.5493
# Epoch 21/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.5514 - accuracy: 0.7848 - val_loss: 1.6536 - val_accuracy: 0.5575
# Epoch 22/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.5103 - accuracy: 0.8007 - val_loss: 1.8258 - val_accuracy: 0.5604
# Epoch 23/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4957 - accuracy: 0.8114 - val_loss: 1.7647 - val_accuracy: 0.5563
# Epoch 24/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.4768 - accuracy: 0.8177 - val_loss: 1.8636 - val_accuracy: 0.5505
# Epoch 25/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4504 - accuracy: 0.8239 - val_loss: 1.9571 - val_accuracy: 0.5517
# Epoch 26/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4420 - accuracy: 0.8303 - val_loss: 2.0619 - val_accuracy: 0.5540
# Epoch 27/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4246 - accuracy: 0.8407 - val_loss: 2.1583 - val_accuracy: 0.5428
# Epoch 28/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.4080 - accuracy: 0.8438 - val_loss: 2.0256 - val_accuracy: 0.5549
# Epoch 29/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.3839 - accuracy: 0.8515 - val_loss: 2.2012 - val_accuracy: 0.5556
# Epoch 30/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.3645 - accuracy: 0.8622 - val_loss: 2.1980 - val_accuracy: 0.5087
# Epoch 31/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.3637 - accuracy: 0.8628 - val_loss: 2.1415 - val_accuracy: 0.5587
# Epoch 32/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.3499 - accuracy: 0.8655 - val_loss: 2.4369 - val_accuracy: 0.5416
# Epoch 33/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.3445 - accuracy: 0.8695 - val_loss: 2.1498 - val_accuracy: 0.5298
# Epoch 34/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.3303 - accuracy: 0.8751 - val_loss: 2.3184 - val_accuracy: 0.5413
# Epoch 35/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.3104 - accuracy: 0.8841 - val_loss: 2.4463 - val_accuracy: 0.5585
# Epoch 36/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.3130 - accuracy: 0.8795 - val_loss: 2.4443 - val_accuracy: 0.5468
# Epoch 37/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2982 - accuracy: 0.8871 - val_loss: 2.5796 - val_accuracy: 0.5381
# Epoch 38/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.2980 - accuracy: 0.8878 - val_loss: 2.7268 - val_accuracy: 0.5554
# Epoch 39/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.2902 - accuracy: 0.8911 - val_loss: 2.7335 - val_accuracy: 0.5204
# Epoch 40/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2796 - accuracy: 0.8937 - val_loss: 2.6202 - val_accuracy: 0.5556
# Epoch 41/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2777 - accuracy: 0.8954 - val_loss: 2.7053 - val_accuracy: 0.5679
# Epoch 42/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.2666 - accuracy: 0.9024 - val_loss: 2.7243 - val_accuracy: 0.5418
# Epoch 43/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.2646 - accuracy: 0.9003 - val_loss: 2.6449 - val_accuracy: 0.5474
# Epoch 44/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.2601 - accuracy: 0.9028 - val_loss: 2.4539 - val_accuracy: 0.5590
# Epoch 45/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2534 - accuracy: 0.9032 - val_loss: 3.0126 - val_accuracy: 0.5538
# Epoch 46/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.2429 - accuracy: 0.9085 - val_loss: 2.7346 - val_accuracy: 0.5604
# Epoch 47/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.2398 - accuracy: 0.9124 - val_loss: 2.8111 - val_accuracy: 0.5387
# Epoch 48/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.2311 - accuracy: 0.9149 - val_loss: 2.7524 - val_accuracy: 0.5623
# Epoch 49/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2311 - accuracy: 0.9133 - val_loss: 2.7185 - val_accuracy: 0.5409
# Epoch 50/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.2217 - accuracy: 0.9184 - val_loss: 3.0596 - val_accuracy: 0.5428
# Epoch 51/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.2161 - accuracy: 0.9197 - val_loss: 2.7076 - val_accuracy: 0.5266
# Epoch 52/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.2254 - accuracy: 0.9180 - val_loss: 2.7326 - val_accuracy: 0.5432
# Epoch 53/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2044 - accuracy: 0.9248 - val_loss: 3.1133 - val_accuracy: 0.5589
# Epoch 54/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2121 - accuracy: 0.9220 - val_loss: 3.0486 - val_accuracy: 0.5467
# Epoch 55/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.2100 - accuracy: 0.9235 - val_loss: 3.8616 - val_accuracy: 0.5273
# Epoch 56/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1938 - accuracy: 0.9275 - val_loss: 3.0869 - val_accuracy: 0.5455
# Epoch 57/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1999 - accuracy: 0.9242 - val_loss: 3.1933 - val_accuracy: 0.5533
# Epoch 58/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2050 - accuracy: 0.9244 - val_loss: 3.2674 - val_accuracy: 0.5550
# Epoch 59/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1896 - accuracy: 0.9305 - val_loss: 3.2305 - val_accuracy: 0.5500
# Epoch 60/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1820 - accuracy: 0.9326 - val_loss: 3.0703 - val_accuracy: 0.5498
# Epoch 61/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1864 - accuracy: 0.9321 - val_loss: 3.2560 - val_accuracy: 0.5510
# Epoch 62/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1818 - accuracy: 0.9338 - val_loss: 2.9745 - val_accuracy: 0.5493
# Epoch 63/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1779 - accuracy: 0.9345 - val_loss: 3.2066 - val_accuracy: 0.5575
# Epoch 64/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1731 - accuracy: 0.9363 - val_loss: 3.0710 - val_accuracy: 0.5406
# Epoch 65/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1794 - accuracy: 0.9360 - val_loss: 3.1031 - val_accuracy: 0.5427
# Epoch 66/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1774 - accuracy: 0.9343 - val_loss: 3.4153 - val_accuracy: 0.5632
# Epoch 67/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1590 - accuracy: 0.9416 - val_loss: 3.3607 - val_accuracy: 0.5462
# Epoch 68/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1639 - accuracy: 0.9401 - val_loss: 3.6291 - val_accuracy: 0.5498
# Epoch 69/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1616 - accuracy: 0.9401 - val_loss: 3.3818 - val_accuracy: 0.5390
# Epoch 70/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1564 - accuracy: 0.9437 - val_loss: 3.4562 - val_accuracy: 0.5449
# Epoch 71/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1596 - accuracy: 0.9415 - val_loss: 3.4370 - val_accuracy: 0.5428
# Epoch 72/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1636 - accuracy: 0.9408 - val_loss: 3.4440 - val_accuracy: 0.5468
# Epoch 73/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1565 - accuracy: 0.9446 - val_loss: 3.4835 - val_accuracy: 0.5549
# Epoch 74/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1450 - accuracy: 0.9477 - val_loss: 3.9465 - val_accuracy: 0.5531
# Epoch 75/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1479 - accuracy: 0.9474 - val_loss: 3.3267 - val_accuracy: 0.5509
# Epoch 76/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1457 - accuracy: 0.9489 - val_loss: 3.6804 - val_accuracy: 0.5399
# Epoch 77/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1512 - accuracy: 0.9448 - val_loss: 3.8953 - val_accuracy: 0.5465
# Epoch 78/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1415 - accuracy: 0.9506 - val_loss: 3.9221 - val_accuracy: 0.5347
# Epoch 79/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1413 - accuracy: 0.9486 - val_loss: 3.7412 - val_accuracy: 0.5467
# Epoch 80/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1464 - accuracy: 0.9484 - val_loss: 3.5777 - val_accuracy: 0.5583
# Epoch 81/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1431 - accuracy: 0.9498 - val_loss: 3.6622 - val_accuracy: 0.5552
# Epoch 82/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1352 - accuracy: 0.9501 - val_loss: 3.7189 - val_accuracy: 0.5515
# Epoch 83/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1315 - accuracy: 0.9519 - val_loss: 3.7224 - val_accuracy: 0.5334
# Epoch 84/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1389 - accuracy: 0.9505 - val_loss: 3.4884 - val_accuracy: 0.5465
# Epoch 85/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1392 - accuracy: 0.9518 - val_loss: 3.5869 - val_accuracy: 0.5474
# Epoch 86/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1396 - accuracy: 0.9519 - val_loss: 3.4153 - val_accuracy: 0.5453
# Epoch 87/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.1364 - accuracy: 0.9523 - val_loss: 3.7290 - val_accuracy: 0.5474
# Epoch 88/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1345 - accuracy: 0.9520 - val_loss: 3.7003 - val_accuracy: 0.5467
# Epoch 89/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1209 - accuracy: 0.9556 - val_loss: 4.1411 - val_accuracy: 0.5376
# Epoch 90/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1203 - accuracy: 0.9575 - val_loss: 3.6919 - val_accuracy: 0.5519
# Epoch 91/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1239 - accuracy: 0.9570 - val_loss: 4.0673 - val_accuracy: 0.5453
# Epoch 92/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1185 - accuracy: 0.9566 - val_loss: 4.2914 - val_accuracy: 0.5552
# Epoch 93/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1149 - accuracy: 0.9575 - val_loss: 4.0773 - val_accuracy: 0.5502
# Epoch 94/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1273 - accuracy: 0.9535 - val_loss: 4.0159 - val_accuracy: 0.5362
# Epoch 95/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1245 - accuracy: 0.9541 - val_loss: 3.9388 - val_accuracy: 0.5474
# Epoch 96/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1112 - accuracy: 0.9593 - val_loss: 5.1760 - val_accuracy: 0.5413
# Epoch 97/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1151 - accuracy: 0.9590 - val_loss: 4.3299 - val_accuracy: 0.5545
# Epoch 98/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.1130 - accuracy: 0.9591 - val_loss: 4.6198 - val_accuracy: 0.5500
# Epoch 99/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1185 - accuracy: 0.9585 - val_loss: 3.9889 - val_accuracy: 0.5580
# Epoch 100/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1121 - accuracy: 0.9602 - val_loss: 4.0372 - val_accuracy: 0.5455

# %%
from sklearn.preprocessing import LabelBinarizer

# Convert integer labels to one-hot encoded format
lb = LabelBinarizer()
Y_test_binary = lb.fit_transform(Y_test)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(7):  # assuming there are 7 classes
    fpr[i], tpr[i], _ = roc_curve(Y_test_binary[:, i], Y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve for each class
plt.figure(figsize=(8, 6))
for i in range(7):
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f) for emotion %d' % (roc_auc[i], i))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
import numpy as np
from sklearn.metrics import precision_score
from sklearn.preprocessing import label_binarize

# Get predicted probabilities for each class
Y_pred_prob = model.predict(X_test)

# Choose a new threshold
new_threshold = 0.9

# Apply the new threshold to convert probabilities to binary predictions
Y_pred_binary = np.where(Y_pred_prob >= new_threshold, 1, 0)

# Convert integer labels to one-hot encoded format
Y_test_onehot = label_binarize(Y_test, classes=np.arange(7))  # assuming 7 classes

# Calculate precision using the new binary predictions and one-hot encoded labels
precision = precision_score(Y_test_onehot, Y_pred_binary, average='weighted')

print("Precision with new threshold:", precision)
# Out:
# 225/225 [==============================] - 1s 3ms/step
# Precision with new threshold: 0.6126676364049001

# %%
from sklearn.metrics import f1_score
from sklearn.preprocessing import label_binarize

# Convert integer labels to one-hot encoded format
Y_test_onehot = label_binarize(Y_test, classes=np.arange(7))  # assuming 7 classes

# Calculate F1 score using the new binary predictions and one-hot encoded labels
f1 = f1_score(Y_test_onehot, Y_pred_binary, average='weighted')

print("F1 score:", f1)
# Out:
# F1 score: 0.546906759495124

# %%
model.save('/content/drive/MyDrive/Thesis2024/fer2013_Model.h5')
