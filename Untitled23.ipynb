# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from sklearn.model_selection import train_test_split

# Load the FER2013 dataset (replace with your actual file path)
df = pd.read_csv('/content/drive/MyDrive/Thesis2024/fer2013.csv')

# Extract pixel values and labels
pixels = df['pixels'].apply(lambda x: np.array(x.split(), dtype='float32'))
labels = df['emotion']

# Normalize pixel values
pixels /= 255.0

# Reshape pixel arrays to (48, 48, 1)
X_train = np.stack(pixels.values).reshape(-1, 48, 48, 1)
Y_train = labels.values
# Out:
# Mounted at /content/drive

# %%
# Split the data into training, validation, and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)

# %%
# Define the CNN architecture
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))  # 7 emotions: anger, disgust, fear, happiness, sadness, surprise, neutral

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Implement early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/100
# 359/359 [==============================] - 5s 9ms/step - loss: 1.8599 - accuracy: 0.2638 - val_loss: 4.5328 - val_accuracy: 0.1567
# Epoch 2/100
# 359/359 [==============================] - 2s 7ms/step - loss: 1.6474 - accuracy: 0.3364 - val_loss: 1.5850 - val_accuracy: 0.3939
# Epoch 3/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.5803 - accuracy: 0.3677 - val_loss: 1.5720 - val_accuracy: 0.3694
# Epoch 4/100
# 359/359 [==============================] - 3s 7ms/step - loss: 1.5286 - accuracy: 0.3920 - val_loss: 1.5199 - val_accuracy: 0.4222
# Epoch 5/100
# 359/359 [==============================] - 3s 7ms/step - loss: 1.4604 - accuracy: 0.4211 - val_loss: 1.4710 - val_accuracy: 0.4211
# Epoch 6/100
# 359/359 [==============================] - 3s 7ms/step - loss: 1.4095 - accuracy: 0.4444 - val_loss: 1.4910 - val_accuracy: 0.4232
# Epoch 7/100
# 359/359 [==============================] - 3s 7ms/step - loss: 1.3579 - accuracy: 0.4635 - val_loss: 1.3994 - val_accuracy: 0.4653
# Epoch 8/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.3213 - accuracy: 0.4784 - val_loss: 1.3436 - val_accuracy: 0.4936
# Epoch 9/100
# 359/359 [==============================] - 3s 7ms/step - loss: 1.2601 - accuracy: 0.5003 - val_loss: 1.4290 - val_accuracy: 0.4763
# Epoch 10/100
# 359/359 [==============================] - 3s 8ms/step - loss: 1.2147 - accuracy: 0.5212 - val_loss: 1.3983 - val_accuracy: 0.4923
# Epoch 11/100
# 359/359 [==============================] - 3s 7ms/step - loss: 1.1758 - accuracy: 0.5313 - val_loss: 1.3978 - val_accuracy: 0.5042
# Epoch 12/100
# 359/359 [==============================] - 3s 8ms/step - loss: 1.1273 - accuracy: 0.5555 - val_loss: 1.3525 - val_accuracy: 0.4925
# Epoch 13/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.0930 - accuracy: 0.5655 - val_loss: 1.3798 - val_accuracy: 0.5019
# Epoch 14/100
# 359/359 [==============================] - 2s 7ms/step - loss: 1.0576 - accuracy: 0.5761 - val_loss: 1.5097 - val_accuracy: 0.4732
# Epoch 15/100
# 359/359 [==============================] - 3s 7ms/step - loss: 1.0330 - accuracy: 0.5879 - val_loss: 1.3753 - val_accuracy: 0.5021
# Epoch 16/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.9901 - accuracy: 0.5982 - val_loss: 1.4945 - val_accuracy: 0.4949
# Epoch 17/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.9605 - accuracy: 0.6141 - val_loss: 1.4587 - val_accuracy: 0.5057
# Epoch 18/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.9403 - accuracy: 0.6159 - val_loss: 1.4236 - val_accuracy: 0.5122
# Epoch 19/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.9195 - accuracy: 0.6235 - val_loss: 1.4444 - val_accuracy: 0.5113
# Epoch 20/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.8802 - accuracy: 0.6385 - val_loss: 1.4765 - val_accuracy: 0.5098
# Epoch 21/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.8724 - accuracy: 0.6442 - val_loss: 1.5476 - val_accuracy: 0.5096
# Epoch 22/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.8614 - accuracy: 0.6495 - val_loss: 1.6208 - val_accuracy: 0.5148
# Epoch 23/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.8304 - accuracy: 0.6591 - val_loss: 1.6199 - val_accuracy: 0.5091
# Epoch 24/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.8214 - accuracy: 0.6635 - val_loss: 1.6166 - val_accuracy: 0.5199
# Epoch 25/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.8021 - accuracy: 0.6664 - val_loss: 1.6612 - val_accuracy: 0.5277
# Epoch 26/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.7834 - accuracy: 0.6766 - val_loss: 1.5909 - val_accuracy: 0.4920
# Epoch 27/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.7749 - accuracy: 0.6821 - val_loss: 1.7720 - val_accuracy: 0.5110
# Epoch 28/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.7545 - accuracy: 0.6887 - val_loss: 1.7372 - val_accuracy: 0.5152
# Epoch 29/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.7411 - accuracy: 0.6931 - val_loss: 2.0057 - val_accuracy: 0.5040
# Epoch 30/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.7383 - accuracy: 0.6926 - val_loss: 1.7690 - val_accuracy: 0.5111
# Epoch 31/100
# 359/359 [==============================] - 3s 10ms/step - loss: 0.7160 - accuracy: 0.7010 - val_loss: 1.8022 - val_accuracy: 0.5174
# Epoch 32/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.7102 - accuracy: 0.7041 - val_loss: 1.7537 - val_accuracy: 0.5136
# Epoch 33/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.7024 - accuracy: 0.7066 - val_loss: 1.7499 - val_accuracy: 0.5138
# Epoch 34/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.6915 - accuracy: 0.7135 - val_loss: 1.8103 - val_accuracy: 0.5082
# Epoch 35/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.6919 - accuracy: 0.7102 - val_loss: 1.9626 - val_accuracy: 0.5152
# Epoch 36/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.6742 - accuracy: 0.7203 - val_loss: 1.8670 - val_accuracy: 0.5167
# Epoch 37/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.6597 - accuracy: 0.7253 - val_loss: 1.7297 - val_accuracy: 0.5059
# Epoch 38/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.6527 - accuracy: 0.7280 - val_loss: 1.7845 - val_accuracy: 0.5118
# Epoch 39/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.6557 - accuracy: 0.7267 - val_loss: 2.0547 - val_accuracy: 0.5263
# Epoch 40/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.6284 - accuracy: 0.7400 - val_loss: 1.8938 - val_accuracy: 0.5091
# Epoch 41/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.6256 - accuracy: 0.7394 - val_loss: 1.9605 - val_accuracy: 0.4937
# Epoch 42/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.6219 - accuracy: 0.7408 - val_loss: 1.8485 - val_accuracy: 0.5111
# Epoch 43/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.6150 - accuracy: 0.7456 - val_loss: 2.1860 - val_accuracy: 0.5192
# Epoch 44/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.6080 - accuracy: 0.7442 - val_loss: 1.9860 - val_accuracy: 0.5035
# Epoch 45/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.6025 - accuracy: 0.7503 - val_loss: 2.0849 - val_accuracy: 0.5259
# Epoch 46/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.5947 - accuracy: 0.7526 - val_loss: 2.1689 - val_accuracy: 0.5192
# Epoch 47/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.5831 - accuracy: 0.7545 - val_loss: 2.2215 - val_accuracy: 0.5228
# Epoch 48/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.5756 - accuracy: 0.7597 - val_loss: 2.1834 - val_accuracy: 0.5157
# Epoch 49/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.5830 - accuracy: 0.7597 - val_loss: 1.9300 - val_accuracy: 0.4990
# Epoch 50/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.5839 - accuracy: 0.7582 - val_loss: 2.4257 - val_accuracy: 0.5132
# Epoch 51/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.5651 - accuracy: 0.7662 - val_loss: 2.1729 - val_accuracy: 0.5219
# Epoch 52/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.5650 - accuracy: 0.7614 - val_loss: 2.6310 - val_accuracy: 0.5136
# Epoch 53/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.5624 - accuracy: 0.7676 - val_loss: 2.3005 - val_accuracy: 0.5127
# Epoch 54/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.5541 - accuracy: 0.7679 - val_loss: 2.3464 - val_accuracy: 0.5247
# Epoch 55/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.5550 - accuracy: 0.7700 - val_loss: 2.2288 - val_accuracy: 0.5104
# Epoch 56/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.5506 - accuracy: 0.7696 - val_loss: 2.1218 - val_accuracy: 0.5092
# Epoch 57/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.5317 - accuracy: 0.7814 - val_loss: 2.1391 - val_accuracy: 0.5030
# Epoch 58/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.5373 - accuracy: 0.7748 - val_loss: 2.5396 - val_accuracy: 0.5197
# Epoch 59/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.5229 - accuracy: 0.7809 - val_loss: 2.3644 - val_accuracy: 0.5254
# Epoch 60/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.5276 - accuracy: 0.7810 - val_loss: 2.6904 - val_accuracy: 0.5188
# Epoch 61/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.5255 - accuracy: 0.7811 - val_loss: 2.3065 - val_accuracy: 0.5122
# Epoch 62/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.5197 - accuracy: 0.7853 - val_loss: 2.4582 - val_accuracy: 0.5199
# Epoch 63/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.5029 - accuracy: 0.7917 - val_loss: 2.4660 - val_accuracy: 0.5101
# Epoch 64/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.5276 - accuracy: 0.7838 - val_loss: 2.1536 - val_accuracy: 0.5094
# Epoch 65/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4990 - accuracy: 0.7922 - val_loss: 2.3270 - val_accuracy: 0.5152
# Epoch 66/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4977 - accuracy: 0.7911 - val_loss: 2.4994 - val_accuracy: 0.5192
# Epoch 67/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.5008 - accuracy: 0.7929 - val_loss: 2.9346 - val_accuracy: 0.5167
# Epoch 68/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4952 - accuracy: 0.7924 - val_loss: 2.5915 - val_accuracy: 0.5152
# Epoch 69/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.5032 - accuracy: 0.7895 - val_loss: 2.2537 - val_accuracy: 0.5153
# Epoch 70/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4896 - accuracy: 0.7961 - val_loss: 2.7168 - val_accuracy: 0.5251
# Epoch 71/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4882 - accuracy: 0.7959 - val_loss: 3.8615 - val_accuracy: 0.5113
# Epoch 72/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4876 - accuracy: 0.7974 - val_loss: 2.6439 - val_accuracy: 0.5228
# Epoch 73/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4846 - accuracy: 0.8022 - val_loss: 2.5494 - val_accuracy: 0.5265
# Epoch 74/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4852 - accuracy: 0.7988 - val_loss: 2.3232 - val_accuracy: 0.5124
# Epoch 75/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4666 - accuracy: 0.8098 - val_loss: 2.5908 - val_accuracy: 0.5254
# Epoch 76/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4815 - accuracy: 0.7996 - val_loss: 2.5794 - val_accuracy: 0.5120
# Epoch 77/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4638 - accuracy: 0.8067 - val_loss: 2.8619 - val_accuracy: 0.5289
# Epoch 78/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4697 - accuracy: 0.8060 - val_loss: 2.7875 - val_accuracy: 0.5266
# Epoch 79/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4606 - accuracy: 0.8086 - val_loss: 2.7863 - val_accuracy: 0.5228
# Epoch 80/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4590 - accuracy: 0.8066 - val_loss: 10.8887 - val_accuracy: 0.4566
# Epoch 81/100
# 359/359 [==============================] - 3s 10ms/step - loss: 0.4656 - accuracy: 0.8067 - val_loss: 2.8912 - val_accuracy: 0.5246
# Epoch 82/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4548 - accuracy: 0.8112 - val_loss: 3.1818 - val_accuracy: 0.5186
# Epoch 83/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4501 - accuracy: 0.8146 - val_loss: 2.6431 - val_accuracy: 0.5165
# Epoch 84/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4507 - accuracy: 0.8120 - val_loss: 2.6026 - val_accuracy: 0.5153
# Epoch 85/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4478 - accuracy: 0.8176 - val_loss: 2.9809 - val_accuracy: 0.5239
# Epoch 86/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4480 - accuracy: 0.8167 - val_loss: 2.6164 - val_accuracy: 0.5244
# Epoch 87/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4370 - accuracy: 0.8204 - val_loss: 3.3204 - val_accuracy: 0.5265
# Epoch 88/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.4451 - accuracy: 0.8169 - val_loss: 2.5434 - val_accuracy: 0.5148
# Epoch 89/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4441 - accuracy: 0.8154 - val_loss: 3.1261 - val_accuracy: 0.5277
# Epoch 90/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4211 - accuracy: 0.8244 - val_loss: 2.8349 - val_accuracy: 0.5235
# Epoch 91/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4399 - accuracy: 0.8183 - val_loss: 3.8713 - val_accuracy: 0.5202
# Epoch 92/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4276 - accuracy: 0.8213 - val_loss: 4.2773 - val_accuracy: 0.5206
# Epoch 93/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4321 - accuracy: 0.8197 - val_loss: 3.2902 - val_accuracy: 0.5237
# Epoch 94/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4268 - accuracy: 0.8239 - val_loss: 2.7734 - val_accuracy: 0.5307
# Epoch 95/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4189 - accuracy: 0.8243 - val_loss: 3.6375 - val_accuracy: 0.5221
# Epoch 96/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4185 - accuracy: 0.8271 - val_loss: 2.7452 - val_accuracy: 0.5152
# Epoch 97/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4261 - accuracy: 0.8220 - val_loss: 3.0824 - val_accuracy: 0.5211
# Epoch 98/100
# 359/359 [==============================] - 3s 8ms/step - loss: 0.4160 - accuracy: 0.8291 - val_loss: 3.2125 - val_accuracy: 0.5263
# Epoch 99/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4215 - accuracy: 0.8280 - val_loss: 3.2427 - val_accuracy: 0.5263
# Epoch 100/100
# 359/359 [==============================] - 3s 7ms/step - loss: 0.4066 - accuracy: 0.8303 - val_loss: 3.0301 - val_accuracy: 0.5244

# %%
model.save('/content/drive/MyDrive/Thesis2024/fer2013_Model.h5')
