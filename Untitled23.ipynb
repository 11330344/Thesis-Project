# %% [markdown]
# <a href="https://colab.research.google.com/github/11330344/Thesis-Project/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from sklearn.model_selection import train_test_split

# Load the FER2013 dataset (replace with your actual file path)
df = pd.read_csv('/content/drive/MyDrive/Thesis2024/fer2013.csv')

# Extract pixel values and labels
pixels = df['pixels'].apply(lambda x: np.array(x.split(), dtype='float32'))
labels = df['emotion']

# Normalize pixel values
pixels /= 255.0

# Reshape pixel arrays to (48, 48, 1)
X_train = np.stack(pixels.values).reshape(-1, 48, 48, 1)
Y_train = labels.values
# Out:
# Mounted at /content/drive

# %%
# Split the data into training, validation, and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))  # 7 emotions: anger, disgust, fear, happiness, sadness, surprise, neutral

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Implement early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
model.fit(X_train, Y_train, epochs=100, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/100
# 359/359 [==============================] - 12s 13ms/step - loss: 1.7735 - accuracy: 0.3104 - val_loss: 1.8707 - val_accuracy: 0.2520
# Epoch 2/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.5484 - accuracy: 0.3837 - val_loss: 1.4563 - val_accuracy: 0.4500
# Epoch 3/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.4446 - accuracy: 0.4337 - val_loss: 1.4086 - val_accuracy: 0.4490
# Epoch 4/100
# 359/359 [==============================] - 4s 10ms/step - loss: 1.3744 - accuracy: 0.4558 - val_loss: 1.4239 - val_accuracy: 0.4586
# Epoch 5/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.3184 - accuracy: 0.4819 - val_loss: 1.3047 - val_accuracy: 0.5103
# Epoch 6/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.2725 - accuracy: 0.5006 - val_loss: 1.5845 - val_accuracy: 0.3488
# Epoch 7/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.2251 - accuracy: 0.5225 - val_loss: 1.2828 - val_accuracy: 0.5089
# Epoch 8/100
# 359/359 [==============================] - 4s 11ms/step - loss: 1.1690 - accuracy: 0.5432 - val_loss: 1.3301 - val_accuracy: 0.5052
# Epoch 9/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.1259 - accuracy: 0.5637 - val_loss: 1.2509 - val_accuracy: 0.5397
# Epoch 10/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.0603 - accuracy: 0.5835 - val_loss: 1.3051 - val_accuracy: 0.5204
# Epoch 11/100
# 359/359 [==============================] - 3s 9ms/step - loss: 1.0140 - accuracy: 0.6020 - val_loss: 1.3862 - val_accuracy: 0.5226
# Epoch 12/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.9621 - accuracy: 0.6272 - val_loss: 1.2805 - val_accuracy: 0.5493
# Epoch 13/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.9094 - accuracy: 0.6440 - val_loss: 1.3801 - val_accuracy: 0.5528
# Epoch 14/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.8627 - accuracy: 0.6661 - val_loss: 1.3557 - val_accuracy: 0.5472
# Epoch 15/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.8093 - accuracy: 0.6845 - val_loss: 1.4021 - val_accuracy: 0.5298
# Epoch 16/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.7741 - accuracy: 0.6988 - val_loss: 1.3219 - val_accuracy: 0.5610
# Epoch 17/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.7227 - accuracy: 0.7172 - val_loss: 1.4917 - val_accuracy: 0.5340
# Epoch 18/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.6889 - accuracy: 0.7325 - val_loss: 1.5179 - val_accuracy: 0.5305
# Epoch 19/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.6560 - accuracy: 0.7430 - val_loss: 1.6320 - val_accuracy: 0.5498
# Epoch 20/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.6195 - accuracy: 0.7561 - val_loss: 1.5985 - val_accuracy: 0.5556
# Epoch 21/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.5835 - accuracy: 0.7715 - val_loss: 1.6571 - val_accuracy: 0.5287
# Epoch 22/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.5575 - accuracy: 0.7844 - val_loss: 1.7144 - val_accuracy: 0.5575
# Epoch 23/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.5400 - accuracy: 0.7936 - val_loss: 1.6649 - val_accuracy: 0.5441
# Epoch 24/100
# 359/359 [==============================] - 3s 10ms/step - loss: 0.5177 - accuracy: 0.7994 - val_loss: 2.1309 - val_accuracy: 0.5404
# Epoch 25/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.4915 - accuracy: 0.8082 - val_loss: 1.8908 - val_accuracy: 0.5402
# Epoch 26/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.4725 - accuracy: 0.8150 - val_loss: 1.9929 - val_accuracy: 0.5610
# Epoch 27/100
# 359/359 [==============================] - 4s 12ms/step - loss: 0.4507 - accuracy: 0.8263 - val_loss: 1.9286 - val_accuracy: 0.5662
# Epoch 28/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.4265 - accuracy: 0.8333 - val_loss: 2.0818 - val_accuracy: 0.5583
# Epoch 29/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.4183 - accuracy: 0.8363 - val_loss: 2.2034 - val_accuracy: 0.5585
# Epoch 30/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.4188 - accuracy: 0.8365 - val_loss: 1.8752 - val_accuracy: 0.5594
# Epoch 31/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.3925 - accuracy: 0.8489 - val_loss: 2.2454 - val_accuracy: 0.5690
# Epoch 32/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.3782 - accuracy: 0.8530 - val_loss: 2.1430 - val_accuracy: 0.5505
# Epoch 33/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.3571 - accuracy: 0.8629 - val_loss: 2.2128 - val_accuracy: 0.5681
# Epoch 34/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.3540 - accuracy: 0.8646 - val_loss: 2.2481 - val_accuracy: 0.5601
# Epoch 35/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.3417 - accuracy: 0.8699 - val_loss: 2.5405 - val_accuracy: 0.5526
# Epoch 36/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.3394 - accuracy: 0.8690 - val_loss: 2.3213 - val_accuracy: 0.5547
# Epoch 37/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.3257 - accuracy: 0.8736 - val_loss: 2.2099 - val_accuracy: 0.5474
# Epoch 38/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.3295 - accuracy: 0.8711 - val_loss: 2.4591 - val_accuracy: 0.5545
# Epoch 39/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2990 - accuracy: 0.8859 - val_loss: 2.5210 - val_accuracy: 0.5489
# Epoch 40/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.3094 - accuracy: 0.8813 - val_loss: 2.3524 - val_accuracy: 0.5509
# Epoch 41/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.3090 - accuracy: 0.8810 - val_loss: 2.7113 - val_accuracy: 0.5531
# Epoch 42/100
# 359/359 [==============================] - 4s 12ms/step - loss: 0.2843 - accuracy: 0.8918 - val_loss: 2.6463 - val_accuracy: 0.5435
# Epoch 43/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2779 - accuracy: 0.8949 - val_loss: 2.5523 - val_accuracy: 0.5540
# Epoch 44/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2660 - accuracy: 0.8986 - val_loss: 2.9265 - val_accuracy: 0.5556
# Epoch 45/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2755 - accuracy: 0.8963 - val_loss: 2.6165 - val_accuracy: 0.5561
# Epoch 46/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.2665 - accuracy: 0.8984 - val_loss: 2.9410 - val_accuracy: 0.5597
# Epoch 47/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2595 - accuracy: 0.9000 - val_loss: 2.4805 - val_accuracy: 0.5578
# Epoch 48/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2495 - accuracy: 0.9065 - val_loss: 2.6745 - val_accuracy: 0.5528
# Epoch 49/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.2433 - accuracy: 0.9086 - val_loss: 2.6693 - val_accuracy: 0.5660
# Epoch 50/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.2411 - accuracy: 0.9085 - val_loss: 2.4044 - val_accuracy: 0.5472
# Epoch 51/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2384 - accuracy: 0.9083 - val_loss: 2.9911 - val_accuracy: 0.5549
# Epoch 52/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2288 - accuracy: 0.9127 - val_loss: 2.8204 - val_accuracy: 0.5571
# Epoch 53/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.2299 - accuracy: 0.9138 - val_loss: 3.0264 - val_accuracy: 0.5655
# Epoch 54/100
# 359/359 [==============================] - 3s 10ms/step - loss: 0.2168 - accuracy: 0.9172 - val_loss: 2.8491 - val_accuracy: 0.5599
# Epoch 55/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2221 - accuracy: 0.9166 - val_loss: 3.0459 - val_accuracy: 0.5500
# Epoch 56/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.2338 - accuracy: 0.9114 - val_loss: 2.9360 - val_accuracy: 0.5664
# Epoch 57/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.2083 - accuracy: 0.9212 - val_loss: 2.9099 - val_accuracy: 0.5402
# Epoch 58/100
# 359/359 [==============================] - 3s 10ms/step - loss: 0.2096 - accuracy: 0.9221 - val_loss: 2.9418 - val_accuracy: 0.5411
# Epoch 59/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1967 - accuracy: 0.9248 - val_loss: 3.2795 - val_accuracy: 0.5657
# Epoch 60/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1932 - accuracy: 0.9269 - val_loss: 3.1541 - val_accuracy: 0.5594
# Epoch 61/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.1845 - accuracy: 0.9296 - val_loss: 3.3877 - val_accuracy: 0.5549
# Epoch 62/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1922 - accuracy: 0.9278 - val_loss: 3.0751 - val_accuracy: 0.5528
# Epoch 63/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1910 - accuracy: 0.9257 - val_loss: 2.9573 - val_accuracy: 0.5582
# Epoch 64/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1865 - accuracy: 0.9297 - val_loss: 3.3145 - val_accuracy: 0.5622
# Epoch 65/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.1851 - accuracy: 0.9318 - val_loss: 3.3109 - val_accuracy: 0.5615
# Epoch 66/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1971 - accuracy: 0.9276 - val_loss: 3.1973 - val_accuracy: 0.5538
# Epoch 67/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1851 - accuracy: 0.9310 - val_loss: 3.3017 - val_accuracy: 0.5672
# Epoch 68/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1661 - accuracy: 0.9370 - val_loss: 3.2786 - val_accuracy: 0.5470
# Epoch 69/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.1725 - accuracy: 0.9369 - val_loss: 3.0091 - val_accuracy: 0.5524
# Epoch 70/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1781 - accuracy: 0.9336 - val_loss: 3.4387 - val_accuracy: 0.5564
# Epoch 71/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1635 - accuracy: 0.9401 - val_loss: 3.4144 - val_accuracy: 0.5610
# Epoch 72/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1662 - accuracy: 0.9376 - val_loss: 3.3227 - val_accuracy: 0.5606
# Epoch 73/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.1733 - accuracy: 0.9357 - val_loss: 3.4783 - val_accuracy: 0.5531
# Epoch 74/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1726 - accuracy: 0.9382 - val_loss: 3.3741 - val_accuracy: 0.5623
# Epoch 75/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1539 - accuracy: 0.9428 - val_loss: 3.8455 - val_accuracy: 0.5575
# Epoch 76/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1556 - accuracy: 0.9430 - val_loss: 3.1835 - val_accuracy: 0.5522
# Epoch 77/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.1588 - accuracy: 0.9422 - val_loss: 2.9801 - val_accuracy: 0.5474
# Epoch 78/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1545 - accuracy: 0.9443 - val_loss: 3.1166 - val_accuracy: 0.5580
# Epoch 79/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1320 - accuracy: 0.9521 - val_loss: 3.7433 - val_accuracy: 0.5610
# Epoch 80/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.1440 - accuracy: 0.9478 - val_loss: 3.3334 - val_accuracy: 0.5556
# Epoch 81/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.1484 - accuracy: 0.9471 - val_loss: 4.3737 - val_accuracy: 0.5488
# Epoch 82/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1380 - accuracy: 0.9505 - val_loss: 3.8109 - val_accuracy: 0.5486
# Epoch 83/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1460 - accuracy: 0.9472 - val_loss: 3.6181 - val_accuracy: 0.5625
# Epoch 84/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.1459 - accuracy: 0.9475 - val_loss: 3.7589 - val_accuracy: 0.5550
# Epoch 85/100
# 359/359 [==============================] - 4s 10ms/step - loss: 0.1482 - accuracy: 0.9477 - val_loss: 3.7817 - val_accuracy: 0.5543
# Epoch 86/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1384 - accuracy: 0.9497 - val_loss: 3.6888 - val_accuracy: 0.5573
# Epoch 87/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1411 - accuracy: 0.9486 - val_loss: 3.7192 - val_accuracy: 0.5596
# Epoch 88/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.1266 - accuracy: 0.9533 - val_loss: 4.1567 - val_accuracy: 0.5667
# Epoch 89/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1328 - accuracy: 0.9528 - val_loss: 3.6278 - val_accuracy: 0.5491
# Epoch 90/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1264 - accuracy: 0.9546 - val_loss: 3.8815 - val_accuracy: 0.5502
# Epoch 91/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1274 - accuracy: 0.9529 - val_loss: 4.1200 - val_accuracy: 0.5590
# Epoch 92/100
# 359/359 [==============================] - 4s 12ms/step - loss: 0.1282 - accuracy: 0.9537 - val_loss: 3.7395 - val_accuracy: 0.5522
# Epoch 93/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1183 - accuracy: 0.9576 - val_loss: 4.1941 - val_accuracy: 0.5442
# Epoch 94/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1298 - accuracy: 0.9532 - val_loss: 3.7425 - val_accuracy: 0.5529
# Epoch 95/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1156 - accuracy: 0.9582 - val_loss: 4.0205 - val_accuracy: 0.5448
# Epoch 96/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.1155 - accuracy: 0.9589 - val_loss: 3.8444 - val_accuracy: 0.5620
# Epoch 97/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1284 - accuracy: 0.9544 - val_loss: 3.6644 - val_accuracy: 0.5538
# Epoch 98/100
# 359/359 [==============================] - 3s 9ms/step - loss: 0.1207 - accuracy: 0.9559 - val_loss: 3.7611 - val_accuracy: 0.5526
# Epoch 99/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.1188 - accuracy: 0.9579 - val_loss: 4.1130 - val_accuracy: 0.5542
# Epoch 100/100
# 359/359 [==============================] - 4s 11ms/step - loss: 0.1208 - accuracy: 0.9565 - val_loss: 4.2652 - val_accuracy: 0.5618

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Convert integer labels to one-hot encoded format
lb = LabelBinarizer()
Y_test_binary = lb.fit_transform(Y_test)
# Get predicted probabilities for each class
Y_pred_prob = model.predict(X_test)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(7):  # assuming there are 7 classes
    fpr[i], tpr[i], _ = roc_curve(Y_test_binary[:, i], Y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve for each class
plt.figure(figsize=(8, 6))
for i in range(7):
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f) for emotion %d' % (roc_auc[i], i))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# 225/225 [==============================] - 1s 4ms/step

# %%
from sklearn.metrics import f1_score
from sklearn.preprocessing import label_binarize

# Convert integer labels to one-hot encoded format
Y_test_onehot = label_binarize(Y_test, classes=np.arange(7))  # assuming 7 classes

# Calculate F1 score using the new binary predictions and one-hot encoded labels
f1 = f1_score(Y_test_onehot, Y_pred_binary, average='weighted')

print("F1 score:", f1)
# Out:
# F1 score: 0.5433272117944717

# %%
import numpy as np
from sklearn.metrics import precision_score
from sklearn.preprocessing import label_binarize

# Get predicted probabilities for each class
Y_pred_prob = model.predict(X_test)

# Choose a new threshold
new_threshold = 0.5

# Apply the new threshold to convert probabilities to binary predictions
Y_pred_binary = np.where(Y_pred_prob >= new_threshold, 1, 0)

# Convert integer labels to one-hot encoded format
Y_test_onehot = label_binarize(Y_test, classes=np.arange(7))  # assuming 7 classes

# Calculate precision using the new binary predictions and one-hot encoded labels
precision = precision_score(Y_test_onehot, Y_pred_binary, average='weighted')

print("Precision with new threshold:", precision)
# Out:
# 225/225 [==============================] - 1s 2ms/step
# Precision with new threshold: 0.5534174835916847

# %%
# Get predicted probabilities for each class
Y_pred_prob = model.predict(X_test)

# Convert probabilities to predicted labels
Y_pred = np.argmax(Y_pred_prob, axis=1)

# Compute confusion matrix
conf_matrix = confusion_matrix(Y_test, Y_pred)
Emotions = ["Angry", "Disgust", "Fear", "Happy", "Sad", "Surprise", "Neutral"]

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=Emotions, yticklabels=Emotions)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 225/225 [==============================] - 1s 4ms/step

# %%
import matplotlib.pyplot as plt

# Assuming you have a pandas DataFrame 'df' with a column 'emotion' representing class labels
class_counts = df['emotion'].value_counts()

# Specify the order of classes
class_order = sorted(class_counts.index)  # Assuming the class labels are numeric

# Plot the distribution of classes
plt.figure(figsize=(10, 6))
class_counts[class_order].plot(kind='bar', color='skyblue')
plt.title('Distribution of Classes')
plt.xlabel('Emotion')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have a pandas DataFrame 'df' with emotion labels
# Count the occurrences of each emotion
emotion_counts = df['emotion'].value_counts()

# Plotting
plt.figure(figsize=(8, 8))
plt.pie(emotion_counts, labels=emotion_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Percentage of Each Emotion in the Dataset')
plt.show()

# %%
import matplotlib.pyplot as plt

# Define emotions and their corresponding labels
emotions = ["Angry", "Disgust", "Fear", "Happy", "Sad", "Surprise", "Neutral"]

# Create a figure with subplots for each emotion
fig, axes = plt.subplots(1, len(emotions), figsize=(15, 3))

# Iterate over each emotion and find a sample for that emotion
for i, emotion in enumerate(emotions):
    # Find the first sample with the current emotion label
    sample = df[df['emotion'] == i].iloc[0]

    # Convert the pixel values to an array and reshape it to the original image dimensions
    pixels = np.array(sample['pixels'].split(), dtype='int').reshape(48, 48)

    # Display the image in the corresponding subplot
    axes[i].imshow(pixels, cmap='gray')
    axes[i].set_title(emotion)
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report

# Get predicted labels
Y_pred = model.predict(X_test)
Y_pred_labels = np.argmax(Y_pred, axis=1)

# Generate classification report
class_report = classification_report(Y_test, Y_pred_labels)

print("Classification Report:\n", class_report)
# Out:
# 225/225 [==============================] - 1s 4ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.42      0.50      0.46       985
#            1       0.77      0.35      0.48       102
#            2       0.41      0.40      0.40      1043
#            3       0.71      0.79      0.75      1765
#            4       0.42      0.39      0.40      1210
#            5       0.69      0.69      0.69       795
#            6       0.55      0.46      0.50      1278
#
#     accuracy                           0.55      7178
#    macro avg       0.57      0.51      0.53      7178
# weighted avg       0.55      0.55      0.54      7178

# %%
model.save('/content/drive/MyDrive/Thesis2024/fer2013_Model.h5')
